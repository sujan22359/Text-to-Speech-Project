# %%
# !pip install pyttsx3
# Out:
# Collecting pyttsx3
#   Downloading pyttsx3-2.98-py3-none-any.whl.metadata (3.8 kB)
# Collecting comtypes (from pyttsx3)
#   Downloading comtypes-1.4.8-py3-none-any.whl.metadata (7.1 kB)
# Collecting pypiwin32 (from pyttsx3)
#   Downloading pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# Requirement already satisfied: pywin32 in c:\users\sujan2004\lib\site-packages (from pyttsx3) (306)
# Downloading pyttsx3-2.98-py3-none-any.whl (34 kB)
# Downloading comtypes-1.4.8-py3-none-any.whl (229 kB)
# Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
# Installing collected packages: pypiwin32, comtypes, pyttsx3
# Successfully installed comtypes-1.4.8 pypiwin32-223 pyttsx3-2.98

# %%
import pyttsx3

def text_to_speech(text):
    engine = pyttsx3.init()
    engine.setProperty('rate', 150) 
    engine.setProperty('volume', 0.9)  
    voices = engine.getProperty('voices')
    for index, voice in enumerate(voices):
        print(f"Voice {index}: {voice.name} ({voice.languages})")
    engine.setProperty('voice', voices[0].id)  
    print("Speaking...")
    engine.say(text)
    engine.runAndWait()
if __name__ == "__main__":
    
    sample_text = "Computational linguistics is a field that combines computer science and linguistics."
    text_to_speech(sample_text)
# Out:
# Voice 0: Microsoft David Desktop - English (United States) ([])
# Voice 1: Microsoft Zira Desktop - English (United States) ([])
# Speaking...

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting spacy
#   Downloading spacy-3.8.3-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.11-cp312-cp312-win_amd64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.10-cp312-cp312-win_amd64.whl.metadata (8.6 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.9-cp312-cp312-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.4.0,>=8.3.0 (from spacy)
#   Downloading thinc-8.3.3-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.0-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.15.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\sujan2004\lib\site-packages (from spacy) (4.66.5)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\sujan2004\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sujan2004\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\sujan2004\lib\site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in c:\users\sujan2004\lib\site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\sujan2004\lib\site-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sujan2004\lib\site-packages (from spacy) (23.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sujan2004\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\sujan2004\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\sujan2004\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sujan2004\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sujan2004\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sujan2004\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sujan2004\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Collecting blis<1.2.0,>=1.1.0 (from thinc<8.4.0,>=8.3.0->spacy)
#   Downloading blis-1.1.0-cp312-cp312-win_amd64.whl.metadata (7.9 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.0->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in c:\users\sujan2004\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\sujan2004\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sujan2004\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.20.0-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sujan2004\lib\site-packages (from jinja2->spacy) (2.1.5)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.1-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sujan2004\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sujan2004\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.17.2)
# Requirement already satisfied: wrapt in c:\users\sujan2004\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sujan2004\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading spacy-3.8.3-cp312-cp312-win_amd64.whl (11.8 MB)
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.8 MB 1.4 MB/s eta 0:00:09
#    -- ------------------------------------- 0.8/11.8 MB 1.5 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/11.8 MB 1.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.6/11.8 MB 1.7 MB/s eta 0:00:06
#    ------- -------------------------------- 2.1/11.8 MB 1.9 MB/s eta 0:00:06
#    --------- ------------------------------ 2.9/11.8 MB 2.2 MB/s eta 0:00:05
#    ------------ --------------------------- 3.7/11.8 MB 2.4 MB/s eta 0:00:04
#    --------------- ------------------------ 4.5/11.8 MB 2.6 MB/s eta 0:00:03
#    ------------------- -------------------- 5.8/11.8 MB 3.0 MB/s eta 0:00:03
#    ------------------------ --------------- 7.1/11.8 MB 3.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.4/11.8 MB 3.6 MB/s eta 0:00:01
#    --------------------------------- ------ 10.0/11.8 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.5/11.8 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 11.0/11.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.8/11.8 MB 3.7 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.10-cp312-cp312-win_amd64.whl (39 kB)
# Downloading langcodes-3.5.0-py3-none-any.whl (182 kB)
# Downloading murmurhash-1.0.11-cp312-cp312-win_amd64.whl (25 kB)
# Downloading preshed-3.0.9-cp312-cp312-win_amd64.whl (122 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.0-cp312-cp312-win_amd64.whl (632 kB)
#    ---------------------------------------- 0.0/632.6 kB ? eta -:--:--
#    --------------------------------------- 632.6/632.6 kB 23.2 MB/s eta 0:00:00
# Downloading thinc-8.3.3-cp312-cp312-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 10.9 MB/s eta 0:00:00
# Downloading typer-0.15.1-py3-none-any.whl (44 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
# Downloading blis-1.1.0-cp312-cp312-win_amd64.whl (6.4 MB)
#    ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/6.4 MB 11.2 MB/s eta 0:00:01
#    -------------- ------------------------- 2.4/6.4 MB 5.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.7/6.4 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 6.4/6.4 MB 7.8 MB/s eta 0:00:00
# Downloading cloudpathlib-0.20.0-py3-none-any.whl (52 kB)
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading language_data-1.3.0-py3-none-any.whl (5.4 MB)
#    ---------------------------------------- 0.0/5.4 MB ? eta -:--:--
#    ------------- -------------------------- 1.8/5.4 MB 12.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.1/5.4 MB 8.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.9/5.4 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 5.4/5.4 MB 7.0 MB/s eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
# Downloading marisa_trie-1.2.1-cp312-cp312-win_amd64.whl (150 kB)
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, smart-open, shellingham, murmurhash, marisa-trie, cloudpathlib, catalogue, blis, srsly, preshed, language-data, typer, langcodes, confection, weasel, thinc, spacy
# Successfully installed blis-1.1.0 catalogue-2.0.10 cloudpathlib-0.20.0 confection-0.1.5 cymem-2.0.10 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.2.1 murmurhash-1.0.11 preshed-3.0.9 shellingham-1.5.4 smart-open-7.1.0 spacy-3.8.3 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.0 thinc-8.3.3 typer-0.15.1 wasabi-1.1.3 weasel-0.4.1
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      ---- ----------------------------------- 1.3/12.8 MB 4.0 MB/s eta 0:00:03
#      ------- -------------------------------- 2.4/12.8 MB 4.3 MB/s eta 0:00:03
#      ------------ --------------------------- 3.9/12.8 MB 5.2 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.5/12.8 MB 5.9 MB/s eta 0:00:02
#      --------------------- ------------------ 6.8/12.8 MB 6.2 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.8 MB 6.8 MB/s eta 0:00:01
#      --------------------------- ------------ 8.9/12.8 MB 6.1 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.8 MB 6.1 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 6.2 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 6.0 MB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def analyze_and_speak(text):
    doc = nlp(text)
    print("Named Entities:")
    for ent in doc.ents:
        print(f"{ent.text} ({ent.label_})")
    text_to_speech(text)

analyze_and_speak(sample_text)
# Out:
# Named Entities:
# Computational (ORG)
# Voice 0: Microsoft David Desktop - English (United States) ([])
# Voice 1: Microsoft Zira Desktop - English (United States) ([])
# Speaking...
